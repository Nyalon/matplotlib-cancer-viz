# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')
mouse = '../resources/mousedrug.csv'
trials = '../resources/trials.csv'

# %%
mouse_data = pd.read_csv(mouse)
clin_trials = pd.read_csv(trials)
mouse_data.head()
# Out:
#   Mouse ID      Drug
# 0     f234  Stelasyn
# 1     x402  Stelasyn
# 2     a492  Stelasyn
# 3     w540  Stelasyn
# 4     v764  Stelasyn

# %%
trial_data = pd.merge(mouse_data, clin_trials, on="Mouse ID")

# %%
trial_data.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %%
tr_treat = trial_data.groupby(["Drug", "Timepoint"])
tr_mean = tr_treat["Tumor Volume (mm3)"].mean()
tr_mean2 = pd.DataFrame(tr_mean)
tr_mean3 = tr_mean2.reset_index()
tr_mean3.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
tr_sem = tr_treat["Tumor Volume (mm3)"].sem()
tr_sem2 = pd.DataFrame(tr_sem)
tr_sem3 = tr_sem2.reset_index()
tr_sem3.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
group_df = trial_data.groupby(["Timepoint", "Drug"])
group_df2 = group_df["Tumor Volume (mm3)"].mean()
group_df3 = pd.DataFrame(group_df2)
group_df4 = group_df3.reset_index()
group_df5 = group_df4.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
group_df5
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
group_sem1 = trial_data.groupby(["Timepoint", "Drug"])
group_sem2 = group_sem1["Tumor Volume (mm3)"].sem()
group_sem3 = pd.DataFrame(group_sem2)
group_sem4 = group_sem3.reset_index()
group_sem5 = group_sem4.pivot(index='Timepoint', columns='Drug', values='Tumor Volume (mm3)')
group_sem5
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182
# 25         0.577401  0.746991  0.741922   0.602513
# 30         0.746045  0.864906  0.899548   0.800043
# 35         1.084929  0.967433  1.003186   0.881426
# 40         1.564779  1.128445  1.410435   0.998515
# 45         1.888586  1.226805  1.576556   1.003576

# %%
plt.figure(figsize=(13, 9))
plt.subplot(4,4,1)
plt.subplots_adjust(top=1.35, right=1.2)
plt.errorbar(group_df5.index, group_df5["Capomulin"], yerr=group_sem5["Capomulin"], fmt="o", color="g",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,2)
plt.errorbar(group_df5.index, group_df5["Ceftamin"], yerr=group_sem5["Ceftamin"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Ceftamin Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,3)
plt.errorbar(group_df5.index, group_df5["Infubinol"], yerr=group_sem5["Infubinol"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Infubinol Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,4)
plt.errorbar(group_df5.index, group_df5["Ketapril"], yerr=group_sem5["Ketapril"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Ketapril Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,5)
plt.errorbar(group_df5.index, group_df5["Naftisol"], yerr=group_sem5["Naftisol"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Naftisol Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,6)
plt.errorbar(group_df5.index, group_df5["Placebo"], yerr=group_sem5["Placebo"], fmt="o", color="blue",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Placebo", fontweight="bold")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,7)
plt.errorbar(group_df5.index, group_df5["Propriva"], yerr=group_sem5["Propriva"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Propriva Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,8)
plt.errorbar(group_df5.index, group_df5["Ramicane"], yerr=group_sem5["Ramicane"], fmt="o", color="g",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Ramicane Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,9)
plt.errorbar(group_df5.index, group_df5["Stelasyn"], yerr=group_sem5["Stelasyn"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Stelasyn Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,10)
plt.errorbar(group_df5.index, group_df5["Zoniferol"], yerr=group_sem5["Zoniferol"], fmt="o", color="r",
            alpha=0.4, label="Mean of Tumor Size")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Zoniferol Tumor Change", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

# %%
msites = trial_data.groupby(["Drug", "Timepoint"])
msites2 = msites["Metastatic Sites"].mean()
msites3 = msites2.reset_index()
msites4 = msites3.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
msites4
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118
# 25         1.357143  0.652174  1.157895   1.687500
# 30         1.615385  0.782609  1.388889   1.933333
# 35         2.300000  0.952381  1.562500   2.285714
# 40         2.777778  1.100000  1.583333   2.785714
# 45         2.571429  1.250000  1.727273   3.071429

# %%
semsites = trial_data.groupby(["Drug", "Timepoint"])
semsites2 = semsites["Metastatic Sites"].sem()
semsites3 = semsites2.reset_index()
semsites4 = semsites3.pivot(index='Timepoint', columns='Drug', values='Metastatic Sites')
semsites4
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378
# 25         0.199095  0.119430  0.219824   0.236621
# 30         0.266469  0.139968  0.230641   0.248168
# 35         0.366667  0.145997  0.240983   0.285714
# 40         0.433903  0.160591  0.312815   0.299791
# 45         0.428571  0.190221  0.359062   0.286400

# %%
plt.figure(figsize=(13, 9))
plt.subplot(4,4,1)
plt.subplots_adjust(top=1.35, right=1.2)
plt.errorbar(semsites4.index, msites4["Capomulin"], yerr=semsites4["Capomulin"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Capomulin)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,2)
plt.errorbar(semsites4.index, msites4["Ceftamin"], yerr=semsites4["Ceftamin"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Ceftamin)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,3)
plt.errorbar(semsites4.index, msites4["Infubinol"], yerr=semsites4["Infubinol"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Infubinol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,4)
plt.errorbar(semsites4.index, msites4["Ketapril"], yerr=semsites4["Ketapril"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Ketapril)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,5)
plt.errorbar(semsites4.index, msites4["Naftisol"], yerr=semsites4["Naftisol"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Naftisol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,6)
plt.errorbar(semsites4.index, msites4["Placebo"], yerr=semsites4["Placebo"], fmt="o", color="b",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Placebo)", fontweight="bold")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,7)
plt.errorbar(semsites4.index, msites4["Propriva"], yerr=semsites4["Propriva"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Propriva)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,8)
plt.errorbar(semsites4.index, msites4["Ramicane"], yerr=semsites4["Ramicane"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Ramicane)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,9)
plt.errorbar(semsites4.index, msites4["Stelasyn"], yerr=semsites4["Stelasyn"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Stelasyn)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,10)
plt.errorbar(semsites4.index, msites4["Zoniferol"], yerr=semsites4["Zoniferol"], fmt="o", color="r",
            alpha=0.4)
plt.ylabel("# Of Metastatic Sites")
plt.title("Met Sites Over Time (Zoniferol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

# %%
mouseper = trial_data.groupby(["Drug", "Timepoint"])
mouseper2 = mouseper["Mouse ID"].count()
mouseper3 = mouseper2.reset_index()
mouseper4 = mouseper3.pivot(index='Timepoint', columns='Drug', values='Mouse ID')
mouseper4
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17
# 25               14        23        19         16
# 30               13        23        18         15
# 35               10        21        16         14
# 40                9        20        12         14
# 45                7        20        11         14

# %%
plt.figure(figsize=(13, 9))
plt.subplot(4,4,1)
plt.subplots_adjust(top=1.35, right=1.2)
plt.scatter(mouseper4.index, mouseper4["Capomulin"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Capomulin)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,2)
plt.scatter(mouseper4.index, mouseper4["Ceftamin"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Ceftamin)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,3)
plt.scatter(mouseper4.index, mouseper4["Infubinol"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Infubinol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,4)
plt.scatter(mouseper4.index, mouseper4["Ketapril"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Ketapril)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,5)
plt.scatter(mouseper4.index, mouseper4["Naftisol"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Naftisol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,6)
plt.scatter(mouseper4.index, mouseper4["Placebo"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Placebo)", fontweight="bold")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,7)
plt.scatter(mouseper4.index, mouseper4["Propriva"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Propriva)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,8)
plt.scatter(mouseper4.index, mouseper4["Ramicane"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Ramicane)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,9)
plt.scatter(mouseper4.index, mouseper4["Stelasyn"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Stelasyn)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

plt.subplot(4,4,10)
plt.scatter(mouseper4.index, mouseper4["Zoniferol"])
plt.ylabel("# Of Mice")
plt.title("Mouse Survival Rate (Zoniferol)", fontstyle="italic")
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=.3)

# %%
group_df5
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
per_change = []
for x in range(10):  
    val1 = group_df5.iloc[9,x] / group_df5.iloc[0,x]
    val2 = round((val1 - 1) / .01, 2)
    per_change.append(val2)
    val1 = 0
    val2 = 0
d_column = trial_data["Drug"].unique()
d_column.sort()
summarydf = pd.DataFrame({"Drug": d_column, "% Change": per_change})

summarydf
# Out:
#         Drug  % Change
# 0  Capomulin    -19.48
# 1   Ceftamin     42.52
# 2  Infubinol     46.12
# 3   Ketapril     57.03
# 4   Naftisol     53.92
# 5    Placebo     51.30
# 6   Propriva     47.24
# 7   Ramicane    -22.32
# 8   Stelasyn     52.09
# 9  Zoniferol     46.58

# %%
summarydf2 = summarydf.set_index("Drug")

x_axis = np.arange(len(summarydf2))
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(13,3))
bar_list = plt.bar(x_axis, summarydf2["% Change"], alpha=0.5, align="edge", color="red")
plt.xticks(tick_locations, summarydf2.index, rotation="vertical")
plt.title("Tumor Size % Change")
plt.ylabel("Percent Grown / Shrunk")
bar_list[0].set_color('g'), bar_list[7].set_color('g')
# Out:
# (None, None)
